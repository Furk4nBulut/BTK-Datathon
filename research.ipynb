# %%
import pandas as  pd
import numpy as np

# %%
data = pd.read_csv('data/train.csv')
data = data.sample(frac=0.2, random_state=1)  # Veri kümesinin %10'u

data
# Out:
# C:\Users\reyiz\AppData\Local\Temp\ipykernel_1732\2286119605.py:1: DtypeWarning: Columns (13,15,19,30,32,37,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/train.csv')
#        Basvuru Yili  Degerlendirme Puani Cinsiyet      Dogum Tarihi  \
# 23003          2016                 60.0    Erkek        1995-05-30
# 14720          2014                 44.0    Kadın         8/25/1991
# 47357          2020                 36.0    Erkek      3/28/98 0:00
# 14717          2014                 44.0    Kadın         8/20/1991
# 11294          2014                 22.0    Erkek          4/4/1991
# ...             ...                  ...      ...               ...
# 61252          2022                 32.0    Kadın  29.07.2003 00:00
# 21357          2015                 14.0    Erkek          5-Jan-93
# 12099          2014                 58.0    Erkek          8/1/1992
# ...

# %%
#gereksiz verileri
"""
Doğum tarihindeki ay ve gün bilgileri
Doğum yeri

Üniversite adı ?
Lise Adı ?
Lise adı diğer ?
Lise şehir ?

Girişimciklikte üye olduğu klup ismiv ?
Hangi sivil toplum kuruluşunda üye ?

Mezun olunan diğer üniversite adı   ---> Bu veriden eğitim  durumu çıkarılabilir


NLP için
Girişimcilikle ilgili Deneyim
"""
data.drop(['Universite Adi', 'Lise Adi', 'Lise Adi Diger', 'Lise Sehir'], axis=1, inplace=True)

# %%
# kullanılacak kategorik veriler
"""
Cinsiyet
Doğum yeri  ( sadece il kısmı )
İkametgat ( sade il )
üniversite türü
burs alıyor mu?
bölümü
başka üniden mezun mu
Lise türü
Lise bölümü
Lise bölümü diğer
başka kurumdan burs alıor mu
anne eğiiim durumu
anne çalışma durumu
anne sektör
baba eğitim 
baba çalışma
baba sektör
girisimcilik kulubu üye misin
prof spor dalıla meşgul musun
spor dalındaki rölünüz
Aktif bir stk üyesi 
stk prjeine katıldın mı
girişimcilikle iligli deneyimihniz var mı
ingilizce biliyor usnuz
ningilizce seviyniz
"""
# Out:
# '\nCinsiyet\nDoğum yeri  ( sadece il kısmı )\nİkametgat ( sade il )\nüniversite türü\nburs alıyor mu?\nbölümü\nbaşka üniden mezun mu\nLise türü\nLise bölümü\nLise bölümü diğer\nbaşka kurumdan burs alıor mu\nanne eğiiim durumu\nanne çalışma durumu\nanne sektör\nbaba eğitim \nbaba çalışma\nbaba sektör\ngirisimcilik kulubu üye misin\nprof spor dalıla meşgul musun\nspor dalındaki rölünüz\nAktif bir stk üyesi \nstk prjeine katıldın mı\ngirişimcilikle iligli deneyimihniz var mı\ningilizce biliyor usnuz\nningilizce seviyniz\n'

# %%
"""
basvur yılı
dogum yılı
burs yüzdesi
kacıncı ınıf
not ortalaması
lise mezuniyet notu
kardeş sayısı

"""
# Out:
# '\nbasvur yılı\ndogum yılı\nburs yüzdesi\nkacıncı ınıf\nnot ortalaması\nlise mezuniyet notu\nkardeş sayısı\n\n'

# %%
def extract_city_only(city_string):
    # Eğer veri float ise (NaN ya da başka sayısal değerler olabilir) atla
    if isinstance(city_string, float):
        return city_string
    
    # Tüm karakterleri küçük harfe çevir
    city_string = city_string.lower()
    
    # Farklı ayırıcılarla şehir bilgilerini al
    separators = [',', '/', '-', ' ']
    for sep in separators:
        if sep in city_string:
            city_string = city_string.split(sep)[-1].strip()  # Sondaki şehri al
    
    # Şehir ismini büyük harfle başlatarak döndür
    return city_string.capitalize()

# 'Dogum Yeri' sütununu sadece il adına göre temizle
data['Dogum Yeri'] = data['Dogum Yeri'].apply(extract_city_only)

# Temizlenmiş veriyi görüntüleme
print(data['Dogum Yeri'].unique())
# Out:
# ['İstanbul' 'Antalya' 'Erzurum' 'Istanbul' 'Van' 'Adana' 'Mersin'
#  'Kocaeli' 'Eskişehir' 'Hakkari' 'Şanlıurfa' 'Nevşehir' 'Diger'
#  'Balıkesir' 'Batman' 'Amasya' 'Sungurlu' 'Kayseri' 'Ankara'
#  'Kahramanmaras' 'Diğer' 'Tekirdag' 'Bursa' 'Trabzon' nan 'Denizli'
#  'Aydın' 'Niğde' 'İzmir' 'Samsun' 'Mardin' 'Erzincan' 'Osmaniye'
#  'Eski̇şehi̇r' 'Elazığ' 'Sakarya' 'Karabük' 'Bolu' 'Uşak' 'Konya'
#  'Afyonkarahisar' 'Malatya' 'Gaziantep' 'Şırnak' 'Izmir' 'Kahramanmaraş'
#  'Muğla' 'Adıyaman' 'Bağcılar' 'Yozgat' 'Artvin' 'Diyarbakır' 'Beyoğlu'
#  'Diyarbakir' 'Manisa' 'Antakya' 'Çankırı' 'Çanakkale' 'Hatay' 'Balikesir'
#  'Kars' 'K.maraş' 'Aydin' 'Bitlis' 'Isparta' 'Sivas' 'Çorum' 'Tekirdağ'
#  'Iğdır' 'İzmit' 'Tokat' 'Yalova' 'Ist.' 'Çayeli' 'Kilis' 'Başçiftlik'
#  'Karabuk' 'Giresun' 'Siirt' 'Ermenek' 'Kutahya' 'Kütahya' 'Konak'
#  'Bayburt' 'Çayıralan' 'Karaman' 'Kırklareli' 'Kastamonu' 'Burdur'
#  'Bartın' 'Aksaray' 'Tunceli' 'Zonguldak' 'Eskisehir' 'Ağrı' 'Bakırköy'
# ...

# %%
import re
# Tarihlerin normal olduğu durumu işlemeye çalış
def extract_year(date_string):
    try:
        # Tarih formatında yıl çıkarma (tarih doğru formatta olursa)
        return pd.to_datetime(date_string).year
    except (ValueError, TypeError):
        # Eğer format uygun değilse, son dört basamaklı sayıyı yıl olarak al
        match = re.search(r'\b(19|20)\d{2}\b', date_string)
        if match:
            return int(match.group(0))
        return None  # Yıl bulunamazsa None döndür

# 'Dogum Tarihi' sütunundan yıl çıkartma
data['Dogum Tarihi'] = data['Dogum Tarihi'].apply(extract_year)

# Sonuçları görüntüleme
print(data[['Dogum Tarihi', 'Dogum Tarihi']])
# Out:
# C:\Users\reyiz\AppData\Local\Temp\ipykernel_1732\3357897069.py:6: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(date_string).year
# C:\Users\reyiz\AppData\Local\Temp\ipykernel_1732\3357897069.py:6: UserWarning: Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(date_string).year
#        Dogum Tarihi  Dogum Tarihi
# 23003        1995.0        1995.0
# 14720        1991.0        1991.0
# 47357        1998.0        1998.0
# 14717        1991.0        1991.0
# 11294        1991.0        1991.0
# ...             ...           ...
# 61252        2003.0        2003.0
# 21357        1993.0        1993.0
# 12099        1992.0        1992.0
# 9360         2001.0        2001.0
# 6064         2001.0        2001.0
#
# ...

# %%
#tüm bu işlemleri bir fonksiyon içinde toplayalım"
def grab_col_names(dataframe, cat_th=10, car_th=20):
    """
    grab_col_names for given dataframe

    :param dataframe:
    :param cat_th:
    :param car_th:
    :return:
    """

    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]

    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]

    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]

    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f'cat_cols: {len(cat_cols)}')
    print(f'num_cols: {len(num_cols)}')
    print(f'cat_but_car: {len(cat_but_car)}')
    print(f'num_but_cat: {len(num_but_cat)}')

    # cat_cols + num_cols + cat_but_car = değişken sayısı.
    # num_but_cat cat_cols'un içerisinde zaten.
    # dolayısıyla tüm şu 3 liste ile tüm değişkenler seçilmiş olacaktır: cat_cols + num_cols + cat_but_car
    # num_but_cat sadece raporlama için verilmiştir.

    return cat_cols, cat_but_car, num_cols

cat_cols, cat_but_car, num_cols = grab_col_names(data)
# Out:
# Observations: 13025
# Variables: 40
# cat_cols: 22
# num_cols: 4
# cat_but_car: 14
# num_but_cat: 1

# %%
data[cat_but_car].head()
# gereksiz<leri dropla
# Out:
#       Dogum Yeri Ikametgah Sehri  \
# 23003  İstanbul        İstanbul
# 14720    Antalya         Antalya
# 47357    Erzurum        İstanbul
# 14717    Antalya         Antalya
# 11294   Istanbul             NaN
#
#                                                    Bölüm   Lise Bolumu  \
# 23003                                  İktisat (Ekonomi)         Sözel
# 14720                              Elektrik Mühendisliği       Sayısal
# 47357  Siyaset Bilimi ve Uluslararası İlişkiler (%100...       Sayısal
# 14717                              Elektrik Mühendisliği       sayısal
# 11294                                        Antropoloji  Esit agirlik
#
#       Lise Bolum Diger Burs Aldigi Baska Kurum  \
# 23003              NaN                     NaN
# 14720              NaN                     NaN
# 47357              NaN                     NaN
# 14717              NaN                     NaN
# 11294              NaN                     NaN
#
# ...

# %%
data[cat_cols].head()
# Out:
#       Cinsiyet Universite Turu Burs Aliyor mu? Universite Kacinci Sinif  \
# 23003    Erkek          Devlet           Hayır                 Hazırlık
# 14720    Kadın          Devlet           Hayır                        4
# 47357    Erkek          Devlet           Hayır                        3
# 14717    Kadın          Devlet           Hayır                        4
# 11294    Erkek          Devlet           Hayır                        3
#
#       Universite Not Ortalamasi Daha Once Baska Bir Universiteden Mezun Olmus  \
# 23003       Ortalama bulunmuyor                                         Hayır
# 14720               3.00 - 4.00                                         Hayır
# 47357               2.50 - 3.00                                           NaN
# 14717               3.00 - 4.00                                         Hayır
# 11294              2.50 ve altı                                         Hayır
#
# ...

# %%
data[num_cols].head()
# Out:
#        Degerlendirme Puani  Dogum Tarihi  Burslu ise Burs Yuzdesi     id
# 23003                 60.0        1995.0                      NaN  23003
# 14720                 44.0        1991.0                      0.0  14720
# 47357                 36.0        1998.0                      NaN  47357
# 14717                 44.0        1991.0                      0.0  14717
# 11294                 22.0        1991.0                      0.0  11294

# %%
# çok basit bir tahmin leme yağıcaz çıktıyı id ve puanı olarak aydedip verecek hadi kodlayalım target değerlendişme puanı
def outlier_thresholds(dataframe, variable, low_quantile=0.10, up_quantile=0.90):
    quantile_one = dataframe[variable].quantile(low_quantile)
    quantile_three = dataframe[variable].quantile(up_quantile)
    interquantile_range = quantile_three - quantile_one
    up_limit = quantile_three + 1.5 * interquantile_range
    low_limit = quantile_one - 1.5 * interquantile_range
    return low_limit, up_limit
# Aykırı değer kontrolü
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False


for col in num_cols:
    if col != "Degerlendirme Puani":
      print(col, check_outlier(data, col))
# Out:
# Dogum Tarihi True
# Burslu ise Burs Yuzdesi False
# id False

# %%
# Aykırı değerlerin baskılanması
def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit


for col in num_cols:
    if col != "Degerlendirme Puani":
        replace_with_thresholds(data,col)
# Out:
# C:\Users\reyiz\AppData\Local\Temp\ipykernel_1732\4052645286.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-72264.20000000001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit

# %%
def missing_values_table(dataframe, na_name=False):
    na_columns = [col for col in dataframe.columns if dataframe[col].isnull().sum() > 0]

    n_miss = dataframe[na_columns].isnull().sum().sort_values(ascending=False)

    ratio = (dataframe[na_columns].isnull().sum() / dataframe.shape[0] * 100).sort_values(ascending=False)

    missing_data = pd.concat([n_miss, np.round(ratio, 2)], axis=1, keys=['n_miss', 'ratio'])

    print(missing_data, end="\n")

    if na_name:
        return na_columns

missing_values_table(data)
# Out:
#                                                     n_miss  ratio
# Daha Önceden Mezun Olunduysa, Mezun Olunan Üniv...   12932  99.29
# Lise Bolum Diger                                     12697  97.48
# Girisimcilikle Ilgili Deneyiminizi Aciklayabili...   10104  77.57
# Hangi STK'nin Uyesisiniz?                             9903  76.03
# Uye Oldugunuz Kulubun Ismi                            9676  74.29
# Baska Kurumdan Aldigi Burs Miktari                    8920  68.48
# Burs Aldigi Baska Kurum                               8880  68.18
# Burslu ise Burs Yuzdesi                               8480  65.11
# Daha Once Baska Bir Universiteden Mezun Olmus         7426  57.01
# Ingilizce Seviyeniz?                                  7308  56.11
# Anne Sektor                                           6895  52.94
# Spor Dalindaki Rolunuz Nedir?                         6388  49.04
# Stk Projesine Katildiniz Mi?                          5601  43.00
# ...

# %%
def quick_missing_imp(data, num_method="median", cat_length=20, target="Degerlendirme Puani"):
    variables_with_na = [col for col in data.columns if data[col].isnull().sum() > 0]  # Eksik değere sahip olan değişkenler listelenir

    temp_target = data[target]

    print("# BEFORE")
    print(data[variables_with_na].isnull().sum(), "\n\n")  # Uygulama öncesi değişkenlerin eksik değerlerinin sayısı

    # değişken object ve sınıf sayısı cat_lengthe eşit veya altındaysa boş değerleri mode ile doldur
    data = data.apply(lambda x: x.fillna(x.mode()[0]) if (x.dtype == "O" and len(x.unique()) <= cat_length) else x, axis=0)

    # num_method mean ise tipi object olmayan değişkenlerin boş değerleri ortalama ile dolduruluyor
    if num_method == "mean":
        data = data.apply(lambda x: x.fillna(x.mean()) if x.dtype != "O" else x, axis=0)
    # num_method median ise tipi object olmayan değişkenlerin boş değerleri ortalama ile dolduruluyor
    elif num_method == "median":
        data = data.apply(lambda x: x.fillna(x.median()) if x.dtype != "O" else x, axis=0)

    data[target] = temp_target

    print("# AFTER \n Imputation method is 'MODE' for categorical variables!")
    print(" Imputation method is '" + num_method.upper() + "' for numeric variables! \n")
    print(data[variables_with_na].isnull().sum(), "\n\n")

    return data


data = quick_missing_imp(data, num_method="median", cat_length=17)
# Out:
# # BEFORE
# Cinsiyet                                                        38
# Dogum Tarihi                                                    53
# Dogum Yeri                                                     159
# Ikametgah Sehri                                                456
# Universite Turu                                                 50
# Burslu ise Burs Yuzdesi                                       8480
# Bölüm                                                           42
# Universite Kacinci Sinif                                        77
# Universite Not Ortalamasi                                      526
# Daha Once Baska Bir Universiteden Mezun Olmus                 7426
# Lise Turu                                                      202
# Lise Bolumu                                                    199
# Lise Bolum Diger                                             12697
# Lise Mezuniyet Notu                                           1222
# ...

# %%
def rare_encoder(dataframe, rare_perc):
    temp_data = dataframe.copy()

    rare_columns = [col for col in temp_data.columns if temp_data[col].dtypes == 'O'
                    and (temp_data[col].value_counts() / len(temp_data) < rare_perc).any(axis=None)]

    for var in rare_columns:
        tmp = temp_data[var].value_counts() / len(temp_data)
        rare_labels = tmp[tmp < rare_perc].index
        temp_data[var] = np.where(temp_data[var].isin(rare_labels), 'Rare', temp_data[var])

    return temp_data


rare_encoder(data,0.01)
# Out:
#        Basvuru Yili  Degerlendirme Puani Cinsiyet  Dogum Tarihi Dogum Yeri  \
# 23003          2016                 60.0    Erkek        1995.0  İstanbul
# 14720          2014                 44.0    Kadın        1991.0    Antalya
# 47357          2020                 36.0    Erkek        1998.0    Erzurum
# 14717          2014                 44.0    Kadın        1991.0    Antalya
# 11294          2014                 22.0    Erkek        1991.0   Istanbul
# ...             ...                  ...      ...           ...        ...
# 61252          2022                 32.0    Kadın        2003.0  Gaziantep
# 21357          2015                 14.0    Erkek        1993.0  Şanlıurfa
# 12099          2014                 58.0    Erkek        1992.0    Erzurum
# 9360           2021                 14.0    Kadın        2001.0       Rare
# 6064           2021                 30.0    Erkek        2001.0  İstanbul
#
#       Ikametgah Sehri Universite Turu  Burslu ise Burs Yuzdesi  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder


def label_encoder(dataframe, binary_col):
    labelencoder = LabelEncoder()
    dataframe[binary_col] = labelencoder.fit_transform(dataframe[binary_col])
    return dataframe

binary_cols = [col for col in data.columns if data[col].dtypes == "O" and len(data[col].unique()) == 2]

for col in binary_cols:
    label_encoder(data, col)

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

data = one_hot_encoder(data, cat_cols, drop_first=True)

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

data = one_hot_encoder(data, cat_but_car, drop_first=True)

# %%
#degerlendirme puanı için tahinleme modeli
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict


y = data["Degerlendirme Puani"]
X = data.drop(["Degerlendirme Puani"], axis=1)

X.isnull().sum()
y.isnull().sum()
y.fillna(y.mean(), inplace=True)
y.isnull().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Özellikler (X) ve hedef değişken (y)
y = data["Degerlendirme Puani"]
X = data.drop(["Degerlendirme Puani"], axis=1)

# Eksik değerleri kontrol et ve doldur
y.fillna(y.mean(), inplace=True)

# Modeli tanımla ve eğit
model = LinearRegression()
model.fit(X, y)

# %%
# Tahmin yap
y_pred = model.predict(X)

# Performans değerlendirmesi
# Cross-validation ile model değerlendirme
cross_val_scores = cross_val_score(model, X, y, cv=5)
print(f"Cross-Validation Scores: {cross_val_scores}")
print(f"Mean Cross-Validation Score: {cross_val_scores.mean()}")
